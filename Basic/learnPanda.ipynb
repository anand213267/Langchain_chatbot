# %%
import pandas

# %%
import pandas as pd

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pd.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
print(pd.__version__)
# Out:
# 3.0.3

# %%
a = [[2,4,0], [0,8,"red"], ["top",5,7], [9,"yy",8]]

mydata = pd.DataFrame(a, index=["one","two","three","four"], columns=["A", "B", "C"])

print(mydata)
print('------------------------------')
print(mydata.iloc[3,1])
# Out:
#          A   B    C
# one      2   4    0
# two      0   8  red
# three  top   5    7
# four     9  yy    8
# ------------------------------
# yy

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
data = {
    "Days": ["mon", "tue", "wed","thu","fri","sat","sun"],
    "steps": [250, 300, 310, 777, 554, 666, 333]
}

df = pd.DataFrame(data)
print(df.iloc[[0,2]])
# Out:
#   Days  steps
# 0  mon    250
# 2  wed    310

# %%
df = pd.read_csv('C:/Users/dev5v/Downloads/Warranty_claims_of_2026.csv')

print(df)
# Out:
#   Created Date Warranty Claim Number                 Company Name  Category  \
# 0   27/01/2026              TC260005  Pure Cold Solutions Limited       NaN
# 1   27/01/2026              TC260005  Pure Cold Solutions Limited       NaN
# 2   29/01/2026              TC260011                   Thermatic        NaN
# 3   29/01/2026              TC260011                   Thermatic        NaN
# 4   20/02/2026              TC260014  Pure Cold Solutions Limited       NaN
# 5   20/02/2026              TC260014  Pure Cold Solutions Limited       NaN
#
#                   Customer  Account Number Site Finder  \
# 0  Pure Cold Solutions Ltd          412347      Dunelm
# 1  Pure Cold Solutions Ltd          412347      Dunelm
# 2                     B&M,          412586           -
# 3                     B&M,          412586           -
# 4  Pure Cold Solutions Ltd          412347           -
# 5  Pure Cold Solutions Ltd          412347           -
#
# ...
